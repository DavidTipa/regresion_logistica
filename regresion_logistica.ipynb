# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.special as special
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=sns.load_dataset('titanic')
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False  NaN  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 5     man        True  NaN   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %%
df=df.fillna(method='bfill')
df=df.fillna(method='ffill')
# Out:
# C:\Users\hegbj\AppData\Local\Temp\ipykernel_29172\2452451499.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='bfill')
# C:\Users\hegbj\AppData\Local\Temp\ipykernel_29172\2452451499.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill')

# %%
Vars_Indep=df[['pclass','age','fare']]
Vars_Dep=df['alive']

# %%
X=Vars_Indep
y=Vars_Dep

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=None)

# %%
escalar=StandardScaler()

# %%
X_train=escalar.fit_transform(X_train)
X_test=escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo=LogisticRegression()

# %%
algoritmo.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=algoritmo.predict(X_test)
y_pred
# Out:
# array(['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no',
#        'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no',
#        'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes',
#        'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'no',
#        'yes', 'yes', 'no', 'no', 'no', 'no'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
matriz=confusion_matrix(y_test,y_pred)
print('matriz de confusion')
print(matriz)
# Out:
# matriz de confusion
# [[149  21]
#  [ 56  42]]

# %%
from sklearn.metrics import precision_score
precision=precision_score(y_test,y_pred, average='binary', pos_label='yes')
print('precision')
print(precision)
# Out:
# precision
# 0.6666666666666666

# %%
from sklearn.metrics import accuracy_score
exactitud=accuracy_score(y_test,y_pred)
print('exactitud del modelo')
print(exactitud)
# Out:
# exactitud del modelo
# 0.7126865671641791

# %%
from sklearn.metrics import recall_score
sensibilidad=recall_score(y_test,y_pred, average='binary', pos_label='no')
print('sensibilidad')
print(sensibilidad)
# Out:
# sensibilidad
# 0.8764705882352941

# %%
unico= np.unique(df['class'])
unico
# Out:
# array(['First', 'Second', 'Third'], dtype=object)

# %%
df['class']=df['class'].replace(["Second", "Third"], "No First")
df.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked     class  \
# 0          0       3    male  22.0      1      0    7.2500        S  No First
# 1          1       1  female  38.0      1      0   71.2833        C     First
# 2          1       3  female  26.0      0      0    7.9250        S  No First
# 3          1       1  female  35.0      1      0   53.1000        S     First
# 4          0       3    male  35.0      0      0    8.0500        S  No First
# 5          0       3    male  54.0      0      0    8.4583        Q  No First
# 6          0       1    male  54.0      0      0   51.8625        S     First
# 7          0       3    male   2.0      3      1   21.0750        S  No First
# 8          1       3  female  27.0      0      2   11.1333        S  No First
# 9          1       2  female  14.0      1      0   30.0708        C  No First
# 10         1       3  female   4.0      1      1   16.7000        S  No First
# 11         1       1  female  58.0      0      0   26.5500        S     First
# 12         0       3    male  20.0      0      0    8.0500        S  No First
# 13         0       3    male  39.0      1      5   31.2750        S  No First
# 14         0       3  female  14.0      0      0    7.8542        S  No First
# 15         1       2  female  55.0      0      0   16.0000        S  No First
# 16         0       3    male   2.0      4      1   29.1250        Q  No First
# 17         1       2    male  31.0      0      0   13.0000        S  No First
# 18         0       3  female  31.0      1      0   18.0000        S  No First
# 19         1       3  female  35.0      0      0    7.2250        C  No First
# 20         0       2    male  35.0      0      0   26.0000        S  No First
# 21         1       2    male  34.0      0      0   13.0000        S  No First
# 22         1       3  female  15.0      0      0    8.0292        Q  No First
# 23         1       1    male  28.0      0      0   35.5000        S     First
# 24         0       3  female   8.0      3      1   21.0750        S  No First
# 25         1       3  female  38.0      1      5   31.3875        S  No First
# 26         0       3    male  19.0      0      0    7.2250        C  No First
# 27         0       1    male  19.0      3      2  263.0000        S     First
# 28         1       3  female  40.0      0      0    7.8792        Q  No First
# 29         0       3    male  40.0      0      0    7.8958        S  No First
# 30         0       1    male  40.0      0      0   27.7208        C     First
# 31         1       1  female  66.0      1      0  146.5208        C     First
# 32         1       3  female  66.0      0      0    7.7500        Q  No First
# 33         0       2    male  66.0      0      0   10.5000        S  No First
# 34         0       1    male  28.0      1      0   82.1708        C     First
# 35         0       1    male  42.0      1      0   52.0000        S     First
# 36         1       3    male  21.0      0      0    7.2292        C  No First
# 37         0       3    male  21.0      0      0    8.0500        S  No First
# 38         0       3  female  18.0      2      0   18.0000        S  No First
# 39         1       3  female  14.0      1      0   11.2417        C  No First
# 40         0       3  female  40.0      1      0    9.4750        S  No First
# 41         0       2  female  27.0      1      0   21.0000        S  No First
# 42         0       3    male   3.0      0      0    7.8958        C  No First
# 43         1       2  female   3.0      1      2   41.5792        C  No First
# 44         1       3  female  19.0      0      0    7.8792        Q  No First
# 45         0       3    male  18.0      0      0    8.0500        S  No First
# 46         0       3    male  18.0      1      0   15.5000        Q  No First
# 47         1       3  female  18.0      0      0    7.7500        Q  No First
# 48         0       3    male  18.0      2      0   21.6792        C  No First
# 49         0       3  female  18.0      1      0   17.8000        S  No First
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True    C  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 2   woman       False    C  Southampton   yes   True
# 3   woman       False    C  Southampton   yes  False
# 4     man        True    E  Southampton    no   True
# 5     man        True    E   Queenstown    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False    G  Southampton    no  False
# 8   woman       False    G  Southampton   yes  False
# 9   child       False    G    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True    D  Southampton    no   True
# 13    man        True    D  Southampton    no  False
# 14  child       False    D  Southampton    no   True
# 15  woman       False    D  Southampton   yes   True
# 16  child       False    D   Queenstown    no  False
# 17    man        True    D  Southampton   yes   True
# 18  woman       False    D  Southampton    no  False
# 19  woman       False    D    Cherbourg   yes   True
# 20    man        True    D  Southampton    no   True
# 21    man        True    D  Southampton   yes   True
# 22  child       False    A   Queenstown   yes   True
# 23    man        True    A  Southampton   yes   True
# 24  child       False    C  Southampton    no  False
# 25  woman       False    C  Southampton   yes  False
# 26    man        True    C    Cherbourg    no   True
# 27    man        True    C  Southampton    no  False
# 28  woman       False    B   Queenstown   yes   True
# 29    man        True    B  Southampton    no   True
# 30    man        True    B    Cherbourg    no   True
# 31  woman       False    B    Cherbourg   yes  False
# 32  woman       False    D   Queenstown   yes   True
# 33    man        True    D  Southampton    no   True
# 34    man        True    D    Cherbourg    no  False
# 35    man        True    D  Southampton    no  False
# 36    man        True    D    Cherbourg   yes   True
# 37    man        True    D  Southampton    no   True
# 38  woman       False    D  Southampton    no  False
# 39  child       False    D    Cherbourg   yes  False
# 40  woman       False    D  Southampton    no  False
# 41  woman       False    D  Southampton    no  False
# 42    man        True    D    Cherbourg    no   True
# 43  child       False    D    Cherbourg   yes  False
# 44  woman       False    D   Queenstown   yes   True
# 45    man        True    D  Southampton    no   True
# 46    man        True    D   Queenstown    no  False
# 47  woman       False    D   Queenstown   yes   True
# 48    man        True    D    Cherbourg    no  False
# 49  woman       False    D  Southampton    no  False
